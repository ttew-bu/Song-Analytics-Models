# %%
import pandas as pd
import numpy as np
import re
from collections import Counter

# %% [markdown]
# The cleaning process for this model will be multiple fold in order to create the data that will be used to create the genre guesser for the web app. Step one will be to clear blanks and delete junk columns

# %%
df = pd.read_csv('C:/Users/trist/OneDrive/Desktop/NLPify_Raw_Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1             artist               track  \
# 0           0             0  Montgomery Gentry           Lucky Man
# 1           1             1       Pretty Ricky      On The Hotline
# 2           2             2   Billy Currington     I Got A Feelin'
# 3           3             3       Alan Jackson   Where I Come From
# 4           4             4         Tim McGraw  Nothin' To Die For
#
#                                               genres  \
# 0  ['contemporary country', 'country', 'country r...
# 1  ['dance pop', 'dirty south rap', 'hip hop', 'h...
# 2  ['contemporary country', 'country', 'country r...
# 3  ['contemporary country', 'country', 'country r...
# 4  ['contemporary country', 'country', 'country r...
#
#                                               lyrics
# 0  [Verse 1]\nI have days where I hate my job\nTh...
# 1  [Hook: Pleasure]\nIt's five in the mornin'\nAn...
# 2  [Verse 1]\nI don't want to rush this thing\nI ...
# 3  [Verse 1]\nWell I was rolling wheels and shift...
# 4  [Verse 1]\nStopped to have a few at five now y...

# %%
df = df.loc[:,['artist','track','genres','lyrics']]

# %%
#Check shape before quick cleaning process
df.shape
# Out:
# (250, 4)

# %%
#Remove blank genre rows from the dataset
df = df[df['genres']!="[]"]

# %%
#Remove empty lyrics songs
df = df[df["lyrics"]!=np.nan]

# %%
#Check shape after quick cleaning process
df.shape
# Out:
# (244, 4)

# %% [markdown]
# Begin the cleaning process for the genres; at the end, you should convert the string (which becomes a list) of genres to one "outcome"

# %%
#Notice since some genre columns have duplicates (e.g. hip hop twice), convert to list and remove duplicates
for row in df['genres']:
        
    #Convert to a list instead of string 
    raw_row = re.findall("'(.*?)'",row)
    
    #Use set to get unique values for each row
    row = set(raw_row)
    print(row)
# Out:
# {'modern country rock', 'country', 'redneck', 'contemporary country', 'country road'}
# {'pop r&b', 'dance pop', 'pop rap', 'hip hop', 'rap', 'urban contemporary', 'southern hip hop', 'dirty south rap', 'r&b', 'trap', 'miami hip hop', 'hip pop'}
# {'country road', 'country', 'contemporary country'}
# {'country road', 'country', 'contemporary country'}
# {'country road', 'country', 'contemporary country'}
# {'country road', 'country', 'contemporary country'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'modern country rock', 'country', 'redneck', 'contemporary country', 'country road'}
# {'post-teen pop', 'modern rock', 'pop rock', 'pop punk', 'neo mellow'}
# {'east coast hip hop', 'pop rap', 'new jack swing', 'hip hop', 'rap', 'hardcore hip hop', 'urban contemporary', 'southern hip hop', 'neo soul', 'r&b', 'gangster rap', 'bronx hip hop', 'hip pop', 'quiet storm'}
# {'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'hardcore hip hop', 'new orleans rap', 'trap', 'gangster rap', 'bronx hip hop', 'hip pop'}
# {'country dawn', 'oklahoma country', 'country', 'contemporary country'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'funk metal', 'pop rock', 'alternative rock', 'alternative metal', 'neo mellow'}
# {'dance pop', 'pop rap', 'urban contemporary', 'r&b', 'british soul'}
# {'dance pop', 'pop'}
# {'bassline', 'pop rap', 'new jack swing', 'urban contemporary', 'r&b', 'hip pop', 'pop r&b'}
# {'nu metal', 'rap metal', 'alternative metal', 'rap rock'}
# {'post-teen pop', 'dance pop', 'east coast hip hop', 'pop rap', 'pop', 'hip hop', 'rap', 'urban contemporary', 'gangster rap', 'hip pop', 'queens hip hop'}
# {'post-grunge', 'nu metal', 'modern rock', 'alternative metal'}
# {'dance pop', 'st louis rap', 'pop rap', 'hip hop', 'rap', 'urban contemporary', 'southern hip hop', 'dirty south rap', 'trap', 'gangster rap'}
# {'post-teen pop', 'dance pop', 'idol', 'lds youth', 'viral pop'}
# {'oklahoma country', 'country road', 'country', 'contemporary country'}
# {'country dawn', 'oklahoma country', 'country'}
# {'post-teen pop', 'pop punk', 'pop rock', 'neo mellow'}
# {'post-teen pop', 'country dawn', 'country', 'oklahoma country', 'contemporary country', 'country road'}
# {'pop soul', 'pop', 'urban contemporary', 'neo soul', 'r&b'}
# {'post-teen pop', 'dance pop', 'pop', 'electropop', 'neo mellow', 'indie poptimism', 'girl group'}
# {'dance pop', 'pop rap', 'pop', 'hip pop', 'urban contemporary', 'r&b', 'neo soul', 'pop r&b'}
# {'post-grunge', 'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'hardcore hip hop', 'nu metal', 'alternative metal', 'rap metal', 'hip pop'}
# {'modern country rock', 'country', 'redneck', 'contemporary country', 'country road'}
# {'bahamian pop'}
# {'pop soul', 'pop', 'urban contemporary', 'neo soul', 'r&b'}
# {'country road', 'country', 'contemporary country'}
# {'country dawn', 'country road', 'country', 'contemporary country'}
# {'pop rap', 'dirty south rap', 'escape room', 'pop r&b', 'post-teen pop', 'trap queen', 'trap', 'r&b', 'hip pop', 'tennessee hip hop', 'hip hop', 'pop', 'southern hip hop', 'gangster rap', 'miami hip hop', 'rap latina', 'queens hip hop', 'dance pop', 'rap', 'atl hip hop', 'memphis hip hop'}
# {'modern country rock', 'country', 'country rock', 'contemporary country', 'country road'}
# {'australian pop', 'australian country', 'country', 'contemporary country', 'country road'}
# {'comic', 'pop rock', 'canadian pop', 'canadian rock'}
# {'oklahoma country', 'country road', 'country', 'contemporary country'}
# {'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'hardcore hip hop', 'urban contemporary', 'southern hip hop', 'golden age hip hop', 'hip pop', 'old school hip hop', 'queens hip hop'}
# {'blues rock', 'modern blues', 'lilith', 'electric blues'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'urban contemporary', 'dance pop', 'pop'}
# {'post-grunge', 'nu metal', 'alternative metal', 'south african rock'}
# {'canadian punk', 'pop punk', 'canadian rock', 'canadian pop punk'}
# {'pop rap', 'dance pop', 'pop'}
# {'punk', 'pop punk', 'socal pop punk'}
# {'pop punk', 'rock', 'punk', 'irish rock', 'permanent wave'}
# {'pop rap', 'post-teen pop', 'dance pop', 'pop'}
# {'post-grunge', 'nu metal', 'rap metal', 'alternative metal'}
# {'country road', 'modern country rock', 'arkansas country'}
# {'modern country rock', 'country', 'redneck', 'contemporary country', 'country road'}
# {'post-teen pop', 'dance pop', 'pop rock', 'pop', 'urban contemporary', 'neo mellow', 'viral pop'}
# {'post-teen pop', 'dance pop', 'pop rap', 'pop', 'urban contemporary', 'r&b', 'hip pop', 'pop r&b'}
# {'country road', 'country'}
# {'pop rock', 'acoustic pop', 'neo mellow'}
# {'bassline', 'pop rap', 'new jack swing', 'urban contemporary', 'r&b', 'hip pop', 'pop r&b'}
# {'modern country rock', 'country', 'arkansas country', 'contemporary country', 'country road'}
# {'modern rock', 'rock'}
# {'post-grunge', 'funk metal', 'canadian rock', 'wrestling', 'nu metal', 'alternative metal', 'rap rock'}
# {'dance pop', 'pop rap', 'hip hop', 'atl hip hop', 'rap', 'southern hip hop', 'dirty south rap', 'trap', 'gangster rap', 'rap kreyol'}
# {'post-teen pop', 'dance pop', 'pop rap', 'urban contemporary', 'r&b', 'hip pop'}
# {'dance pop', 'pop'}
# {'country road', 'country', 'contemporary country'}
# {'soul', 'hip hop', 'urban contemporary', 'funk', 'neo soul', 'r&b', 'indie soul'}
# {'hollywood', 'post-teen pop', 'dance pop', 'show tunes', 'pop', 'movie tunes'}
# {'electro', 'filter house'}
# {'dance pop', 'pop rap', 'pop', 'canadian latin', 'canadian pop'}
# {'alberta country', 'canadian contemporary country', 'country', 'canadian country', 'country dawn', 'country rock', 'contemporary country', 'country road'}
# {'latin hip hop', 'chicano rap'}
# {'latin pop'}
# {'post-teen pop', 'dance pop', 'pop', 'urban contemporary', 'r&b', 'hip pop', 'pop r&b'}
# {'pop rap', 'hip hop', 'rap', 'urban contemporary', 'southern hip hop', 'trap', 'philly rap', 'battle rap', 'hip pop'}
# {'dance pop', 'pop rap', 'pop', 'urban contemporary', 'r&b', 'neo soul', 'hip pop'}
# {'post-grunge', 'pop rock', 'alternative metal', 'neo mellow'}
# {'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'gangster rap', 'queens hip hop'}
# {'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'new orleans rap', 'trap'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'dance pop', 'boy band', 'pop rap', 'hip hop', 'urban contemporary', 'r&b', 'hip pop'}
# {'urban contemporary', 'dance pop', 'pop'}
# {'dance pop', 'pop rap', 'crunk', 'alternative hip hop', 'conscious hip hop', 'hip hop', 'atl hip hop', 'rap', 'political hip hop', 'southern hip hop', 'dirty south rap', 'trap', 'escape room', 'gangster rap'}
# {'pop rap', 'hip hop', 'rap', 'southern hip hop', 'detroit hip hop', 'gangster rap'}
# {'dance pop', 'pop rock', 'pop', 'piano rock'}
# {'dance pop', 'pop rap', 'pop', 'hip hop', 'rap', 'urban contemporary', 'new orleans rap', 'southern hip hop', 'trap', 'r&b', 'hip pop', 'pop r&b'}
# {'post-teen pop', 'dance pop', 'pop rap', 'pop', 'urban contemporary', 'girl group'}
# {'gangster rap', 'g funk', 'west coast rap', 'west coast trap'}
# {'dance pop', 'pop rap', 'hip hop', 'rap', 'urban contemporary', 'trap', 'r&b', 'gangster rap', 'hip pop'}
# {'soul', 'new jack swing', 'urban contemporary', 'funk', 'neo soul', 'r&b', 'quiet storm'}
# {'oxford indie', 'rock', 'art rock', 'alternative rock', 'permanent wave', 'melancholia'}
# {'dance pop', 'new jack swing', 'urban contemporary', 'r&b', 'neo soul', 'hip pop'}
# {'country road', 'country rock', 'country'}
# {'dance pop', 'pop rap', 'crunk', 'hip hop', 'rap', 'urban contemporary', 'southern hip hop', 'dirty south rap', 'gangster rap', 'hip pop'}
# {'lilith', 'alternative pop', 'power pop', 'anti-folk', 'pop rock', 'alternative rock', 'new wave pop', 'permanent wave', 'folk', 'candy pop'}
# {'post-teen pop', 'dance pop', 'pop'}
# {'dance pop', 'pop rap', 'new jack swing', 'hip hop', 'atl hip hop', 'urban contemporary', 'southern hip hop', 'r&b', 'neo soul', 'hip pop', 'quiet storm'}
# {'post-grunge', 'nu metal', 'alternative metal', 'canadian rock'}
# {'post-teen pop', 'dance pop', 'pop', 'urban contemporary', 'miami hip hop'}
# {'texas country'}
# {'tribal house', 'vocal house'}
# {'modern country rock', 'country', 'arkansas country', 'contemporary country', 'country road'}
# {'new jack swing', 'hip hop', 'urban contemporary', 'r&b', 'neo soul', 'hip pop', 'quiet storm'}
# {'dance pop', 'pop rock', 'lovers rock', 'dancehall', 'old school dancehall', 'alternative rock', 'soca', 'permanent wave', 'reggae fusion', 'dance rock'}
# {'pop rap', 'hip hop', 'rap', 'new orleans rap', 'trap'}
# {'dance pop', 'pop rap', 'hip hop', 'pop', 'rap', 'urban contemporary', 'southern hip hop', 'dirty south rap', 'trap', 'gangster rap', 'r&b'}
# {'big beat'}
# {'pop soul', 'pop', 'atl hip hop', 'urban contemporary', 'southern hip hop', 'dirty south rap', 'neo soul', 'r&b'}
# {'country road', 'country', 'contemporary country'}
# {'salsa', 'latin', 'latin pop', 'modern salsa', 'tropical'}
# {'dance pop', 'pop rap', 'pop', 'urban contemporary', 'r&b'}
# {'country road', 'country', 'contemporary country'}
# {'modern country rock', 'country', 'country rock', 'contemporary country', 'country road'}
# {'post-grunge', 'nu metal', 'rap metal', 'alternative metal'}
# {'post-teen pop', 'modern rock', 'pop rock', 'pop punk', 'neo mellow'}
# {'emo', 'pop punk', 'pop rock', 'neo mellow'}
# {'dance pop', 'pop', 'hip hop', 'urban contemporary', 'r&b', 'hip pop'}
# {'dance pop', 'pop rap', 'pop', 'hip hop', 'rap', 'urban contemporary', 'r&b', 'philly rap', 'gangster rap', 'neo soul', 'hip pop'}
# {'dance pop', 'latin', 'latin pop', 'mexican pop', 'puerto rican pop'}
# {'wrestling', 'vocal house'}
# {'kids dance party'}
# {'post-teen pop', 'dance pop', 'pop rap', 'pop', 'electropop', 'viral pop', 'social media pop'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'country', 'lounge', 'oklahoma country', 'jazz pop', 'contemporary country', 'canadian pop', 'adult standards', 'country road'}
# {'australian pop', 'australian country', 'country', 'contemporary country', 'country road'}
# {'country road', 'country', 'contemporary country'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'oklahoma country', 'country road', 'country', 'contemporary country'}
# {'modern country rock', 'country', 'redneck', 'contemporary country', 'country road'}
# {'dance pop', 'east coast hip hop', 'quiet storm', 'pop rap', 'new jack swing', 'hip hop', 'rap', 'urban contemporary', 'funk', 'r&b', 'gangster rap', 'hip pop', 'queens hip hop'}
# {'pop rap', 'hip hop', 'rap', 'new orleans rap', 'canadian hip hop', 'southern hip hop', 'dirty south rap', 'trap', 'toronto rap', 'gangster rap', 'canadian pop'}
# {'pop rap', 'crunk', 'hip hop', 'rap', 'southern hip hop', 'dirty south rap', 'trap', 'gangster rap', 'miami hip hop', 'hip pop'}
# {'country dawn'}
# {'dance pop', 'country dawn', 'country', 'contemporary country', 'country road'}
# {'dance pop', 'boy band'}
# {'emo', 'screamo', 'pop punk', 'pop rock'}
# {'post-grunge', 'nu metal', 'alternative metal', 'canadian rock'}
# {'skate punk', 'screamo', 'pop punk', 'punk', 'alternative metal', 'emo'}
# {'dance pop', 'latin', 'latin arena pop', 'pop', 'latin pop', 'colombian pop', 'cantautor', 'spanish pop', 'mexican pop', 'rock en espanol'}
# {'post-teen pop', 'dance pop', 'pop'}
# {'dance pop', 'country dawn', 'country', 'contemporary country', 'country road'}
# {'post-teen pop', 'dance pop', 'st louis rap', 'pop rap', 'hip hop', 'pop', 'rap', 'urban contemporary', 'southern hip hop'}
# {'pop rap', 'hip hop', 'rap', 'atl hip hop', 'southern hip hop', 'dirty south rap', 'trap'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'dance pop', 'latin', 'pop', 'latin pop', 'mexican pop'}
# {'pop rap', 'new jack swing', 'hip hop', 'hip pop', 'urban contemporary', 'r&b', 'neo soul', 'pop r&b', 'quiet storm'}
# {'pop', 'post-teen pop', 'dance pop', 'boy band'}
# {'dance pop', 'pop rap', 'bubblegum dance', 'europop', 'eurodance', 'german techno', 'melbourne bounce international'}
# {'indie pop', 'pop rock', 'indie rock', 'modern rock', 'washington indie'}
# {'indietronica', 'modern rock', 'rock', 'indie rock', 'alternative dance'}
# {'latin hip hop', 'electro latino', 'latin', 'reggaeton', 'trap latino'}
# {'boy band', 'new jack swing', 'urban contemporary', 'r&b', 'funk', 'hip pop', 'quiet storm'}
# {'dance pop', 'pop rap', 'hip hop', 'pop', 'urban contemporary', 'hip pop'}
# {'dance pop', 'east coast hip hop', 'alternative hip hop', 'pop rap', 'hip hop', 'rap', 'hardcore hip hop', 'urban contemporary', 'electropop', 'r&b', 'gangster rap', 'neo soul', 'hip pop'}
# {'acoustic pop', 'ann arbor indie'}
# {'new jack swing', 'hip pop', 'urban contemporary', 'neo soul', 'r&b', 'quiet storm'}
# {'dance pop'}
# {'hip hop', 'east coast hip hop', 'pop rap', 'rap'}
# {'pop', 'post-teen pop', 'dance pop', 'boy band'}
# {'dance pop', 'pop rap', 'pop', 'hip pop', 'urban contemporary', 'r&b', 'neo soul', 'pop r&b'}
# {'emo', 'bow pop', 'pop punk', 'socal pop punk'}
# {'pop punk', 'pixie', 'pop emo', 'emo', 'candy pop'}
# {'dance pop', 'east coast hip hop', 'pop rap', 'new jack swing', 'hip hop', 'rap', 'urban contemporary', 'r&b', 'neo soul', 'hip pop', 'quiet storm'}
# {'pop rap', 'crunk', 'hip hop', 'rap', 'bounce', 'new orleans rap', 'southern hip hop', 'dirty south rap', 'trap', 'gangster rap', 'hip pop'}
# {'pop rock', 'pop'}
# {'dance pop', 'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'hardcore hip hop', 'hip pop'}
# {'country road', 'country', 'contemporary country'}
# {'country road', 'country rock', 'country', 'contemporary country'}
# {'modern country rock', 'country', 'redneck', 'country rock', 'contemporary country', 'country road'}
# {'dance pop', 'pop rap', 'pop', 'hip pop', 'urban contemporary', 'r&b', 'neo soul', 'pop r&b'}
# {'dance pop', 'pop rap', 'atl hip hop', 'urban contemporary', 'southern hip hop', 'r&b', 'girl group', 'hip pop', 'pop r&b'}
# {'post-grunge', 'nu metal', 'modern rock', 'alternative metal'}
# {'post-teen pop', 'dance pop', 'pop rap', 'pop', 'miami hip hop'}
# {'pop rap', 'hip hop', 'rap', 'atl hip hop', 'chicago rap', 'southern hip hop', 'dirty south rap', 'trap', 'hip pop'}
# {'pop rap', 'trap queen', 'hip pop'}
# {'post-teen pop', 'canadian pop', 'pop'}
# {'reggae fusion', 'barbadian pop'}
# {'post-teen pop', 'country dawn', 'country', 'oklahoma country', 'contemporary country', 'country road'}
# {'pop rap', 'post-teen pop', 'dance pop', 'pop'}
# {'country road', 'country rock', 'country'}
# {'modern country rock', 'country dawn', 'country', 'contemporary country', 'country road'}
# {'country road', 'country', 'contemporary country'}
# {'post-teen pop'}
# {'country road', 'country rock', 'country', 'contemporary country'}
# {'post-teen pop', 'pop'}
# {'country road', 'country rock', 'country', 'contemporary country'}
# {'indiecoustica', 'stomp and holler', 'pop rock', 'indie poptimism', 'neo mellow', 'acoustic pop'}
# {'dance pop', 'country dawn', 'country', 'contemporary country', 'country road'}
# {'metal', 'british power metal', 'speed metal', 'power metal', 'neo classical metal'}
# {'dance pop', 'boy band'}
# {'pop', 'post-teen pop', 'dance pop', 'boy band'}
# {'country road', 'country', 'contemporary country'}
# {'dance pop', 'pop rap', 'crunk', 'hip hop', 'conscious hip hop', 'rap', 'pop', 'atl hip hop', 'mississippi hip hop', 'dirty south rap', 'southern hip hop', 'trap', 'gangster rap', 'r&b'}
# {'modern country rock', 'country', 'country pop', 'contemporary country', 'country road'}
# {'pop rap'}
# {'country road', 'country rock', 'country', 'contemporary country'}
# {'dance pop', 'boy band', 'pop rap', 'new jack swing', 'pop', 'urban contemporary', 'r&b', 'neo soul', 'hip pop'}
# {'pop rap', 'hip hop', 'rap', 'hip pop', 'urban contemporary', 'chicago rap', 'southern hip hop', 'dirty south rap', 'trap', 'gangster rap', 'neo soul', 'r&b'}
# {'post-teen pop', 'dance pop'}
# {'post-teen pop', 'country dawn', 'country', 'oklahoma country', 'contemporary country', 'country road'}
# {'post-grunge', 'modern rock', 'rock', 'alternative rock', 'alternative metal', 'permanent wave'}
# {'pop rap', 'rap', 'atl hip hop', 'southern hip hop', 'dirty south rap', 'trap'}
# {'post-grunge', 'nu metal', 'rap metal', 'alternative metal'}
# {'country dawn', 'country road', 'country', 'contemporary country'}
# {'dance pop', 'latin', 'latin pop', 'mexican pop', 'puerto rican pop'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'dance pop', 'pop rap', 'new jack swing', 'hip hop', 'atl hip hop', 'urban contemporary', 'southern hip hop', 'r&b', 'neo soul', 'hip pop', 'quiet storm'}
# {'dance pop', 'st louis rap', 'pop rap', 'new jack swing', 'hip hop', 'atl hip hop', 'urban contemporary', 'rap', 'southern hip hop', 'r&b', 'neo soul', 'hip pop', 'quiet storm'}
# {'progressive bluegrass', 'lilith', 'country', 'mandolin', 'bluegrass', 'country rock', 'contemporary country', 'folk', 'country road'}
# {'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'gangster rap', 'queens hip hop'}
# {'pop rock', 'acoustic pop', 'neo mellow'}
# {'dub', 'country', 'roots reggae', 'reggae', 'ska', 'contemporary country', 'country road'}
# {'dance pop', 'edm', 'pop', 'pop dance', 'big room'}
# {'alternative hip hop', 'conscious hip hop', 'hip hop', 'rap', 'hardcore hip hop', 'political hip hop', 'chicago rap', 'gangster rap', 'neo soul'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'australian pop', 'dance pop', 'australian dance', 'pop', 'europop', 'electropop', 'new wave pop', 'eurodance'}
# {'modern alternative rock', 'pop rock', 'neo mellow'}
# {'post-teen pop', 'dance pop', 'east coast hip hop', 'pop rap', 'pop', 'hip hop', 'rap', 'urban contemporary', 'barbadian pop'}
# {'rap', 'hip hop', 'detroit hip hop'}
# {'honky tonk', 'outlaw country', 'country', 'country rock', 'country road'}
# {'dance pop', 'hip pop', 'urban contemporary', 'r&b', 'neo soul', 'pop r&b', 'quiet storm'}
# {'pop rap', 'hip hop', 'rap', 'new orleans rap', 'trap'}
# {'modern country rock', 'country', 'country pop', 'contemporary country', 'country road'}
# {'post-grunge', 'nu metal', 'pop rock', 'alternative metal'}
# {'new jack swing', 'hip hop', 'urban contemporary', 'r&b', 'neo soul', 'hip pop', 'quiet storm'}
# {'skate punk', 'punk', 'rock', 'socal pop punk', 'alternative metal', 'permanent wave'}
# {'pop rap', 'post-teen pop', 'dance pop', 'pop'}
# {'modern country rock', 'country', 'country rock', 'contemporary country', 'country road'}
# {'pop rap', 'hip hop', 'rap', 'new orleans rap', 'southern hip hop', 'trap', 'gangster rap'}
# {'lilith', 'pop rock', 'ectofolk', 'neo mellow', 'canadian singer-songwriter', 'new wave pop', 'permanent wave', 'folk', 'canadian pop'}
# {'skate punk', 'screamo', 'pop punk', 'punk', 'alternative metal', 'emo'}
# {'east coast hip hop', 'wu fam', 'hip hop', 'new jersey rap', 'hardcore hip hop', 'rap', 'southern hip hop', 'gangster rap', 'old school hip hop'}
# {'country road', 'country', 'contemporary country'}
# {'boy band'}
# {'country dawn', 'country road', 'country', 'contemporary country'}
# {'east coast hip hop', 'pop rap', 'hip hop', 'rap', 'urban contemporary', 'neo soul', 'r&b'}
# {'dance pop', 'pop'}
# {'country road', 'modern country rock', 'country', 'contemporary country'}
# {'trance', 'funk metal', 'nu metal', 'alternative metal', 'big beat', 'rap rock'}
# {'post-teen pop', 'dance pop', 'pop', 'urban contemporary', 'r&b', 'hip pop', 'pop r&b'}
# {'new jack swing', 'hip hop', 'urban contemporary', 'r&b', 'neo soul', 'hip pop', 'quiet storm'}
# {'country road', 'country', 'contemporary country'}
# {'country road', 'country rock', 'country', 'contemporary country'}
# {'country', 'arkansas country', 'country rock', 'contemporary country', 'country road'}
# {'post-teen pop', 'dance pop', 'pop'}

# %%
genre_word_dict = {}

feed_for_genre_outcome = []

#Iterate through each row in the df to create the dictionary of word frequencies
for row in df['genres']:
    
    #Remove the junk characters from genres by replacing with spaces
    raw_words = row.replace("[","").replace("]","").replace("'","").replace(",","")
    
    #Acknowledge that hip hop , so convert it into the single word hip-hop 
    raw_words = raw_words.replace("hip hop","hip-hop")
    
    #Split up genres by word so we can generalize them later
    individual_words = re.split("\s+",raw_words)
    
    #Create outcome column equating genre to the most common word in the genres column
    feed_for_genre_outcome.append(max(set(individual_words), key=individual_words.count))
    
    #Iterate through each word and send it to the genre word dict
    for word in individual_words:
        if word not in genre_word_dict:
            genre_word_dict[word] = 0
        genre_word_dict[word] += 1
        
#Merge the feeder list to the dataframe 
df['outcome_genre'] = feed_for_genre_outcome
df = df.loc[:,["artist","track","lyrics","outcome_genre"]]

# %%
#Genre data should be done at this point, return the new df
df.head()
# Out:
#               artist               track  \
# 0  Montgomery Gentry           Lucky Man
# 1       Pretty Ricky      On The Hotline
# 2   Billy Currington     I Got A Feelin'
# 3       Alan Jackson   Where I Come From
# 4         Tim McGraw  Nothin' To Die For
#
#                                               lyrics outcome_genre
# 0  [Verse 1]\nI have days where I hate my job\nTh...       country
# 1  [Hook: Pleasure]\nIt's five in the mornin'\nAn...           pop
# 2  [Verse 1]\nI don't want to rush this thing\nI ...       country
# 3  [Verse 1]\nWell I was rolling wheels and shift...       country
# 4  [Verse 1]\nStopped to have a few at five now y...       country

# %% [markdown]
# Begin the lyric cleaning process; strip the lyrics of brackets and then process line breaks.

# %%
#Examine a sample of lyrics to find what must be stripped from the string
df['lyrics'][0]

#Results show that we need to cut brackets, and the EmbedShare UrlCopyEmbedCopy at the end of the string
# Out:
# "[Verse 1]\nI have days where I hate my job\nThis little town and the whole world too\nAnd last Sunday when my Bengals lost\nLord, it put me in a bad mood\n\n[Verse 2]\nI have moments when I curse the rain\nBut then complain when the sun's too hot\nI look around at what everyone has\nAnd I forget about all I've got\n\n[Chorus 1]\nBut I know I'm a lucky man\nGod's given me a pretty fair hand\nGot a house and piece of land\nA few dollars in a coffee can\n\n[Chorus 2]\nMy old truck's still runnin' good\nMy ticker's tickin' like they say it should\nI've got supper in the oven, a good woman's lovin'\nAnd one more day to be my little kid's dad\nLord knows I'm a lucky man\n\n[Verse 3]\nGot some friends who would be here fast\nI could call 'em any time of day\nGot a brother who's got my back\nGot a mama who I swear's a saint\n[Verse 4]\nGot a brand new rod and reel\nGot a full week off this year\nDad had a close call last spring\nIt's a miracle he's still here\n\n[Chorus 1]\nBut I know I'm a lucky man\nGod's given me a pretty fair hand\nGot a house and piece of land\nA few dollars in a coffee can\n\n[Chorus 2]\nMy old truck's still runnin' good\nMy ticker's tickin' like they say it should\nI've got supper in the oven, a good woman's lovin'\nAnd one more day to be my little kids dad\nLord knows I'm a lucky man\n\n[Chorus 2]\nWoh, my old truck's still runnin' good\nMy ticker's tickin' like they say it should\nI've got supper in the oven, a good woman's lovin'\nAnd even my bad days ain't that bad\nYeah, I'm a lucky man\n[Outro]\nI'm a lucky, lucky manEmbedShare URLCopyEmbedCopy"

# %%
# Remove extraneous text (e.g. embedcopy) and verse indicators
new_lyrics = []

#Iterate through the songs
for row in df['lyrics']:
    
    row = str(row)
    
    #remove the embedshare
    row = row.replace("EmbedShare URLCopyEmbedCopy","")
    
    #sub the bracket expressions via regex
    row = re.sub(r"[\[].*?[\]]", "", row)
    
    #sub line breaks out via regex
    row = re.sub(r"\n+", " ", row)
    
    #Convert all upper-case words to lower-case
    row = row.lower()
    
    #add new lyrics to the list that will replace the original column
    new_lyrics.append(row)

#Replace the lyrics column with the cleaned lyrics
df['lyrics'] = new_lyrics

# %%
#As we can see, the genre method at hand right now does not quite word as presented.
df['outcome_genre'].value_counts()
# Out:
# pop            84
# country        69
# rap            25
# metal          15
# soul            9
# hip-hop         9
# rock            8
# punk            5
# band            3
# wave            1
# house           1
# latino          1
# latin           1
# coast           1
# salsa           1
# party           1
# texas           1
# big             1
# vocal           1
# post-grunge     1
# storm           1
# fusion          1
# electro         1
# dance           1
# dawn            1
# blues           1
# Name: outcome_genre, dtype: int64
